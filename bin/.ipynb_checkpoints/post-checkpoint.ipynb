# %%
import gdal
from PIL import Image
import os
from matplotlib import pyplot as plt
from glob import glob
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Quick check of the output data to assess image quality and need for additional post-processing

# %%
#open the output geotiff and explore the alpha channel to replace the strange "cloud of war"-like appearance
output_files = sorted(glob('/contents/bin/out/*.tif'))
print(output_files)
# Out:
# ['/contents/bin/out/m_3711401_ne_11_1_20150725.tif', '/contents/bin/out/m_3711401_nw_11_1_20150725.tif', '/contents/bin/out/m_3711401_se_11_1_20150726.tif', '/contents/bin/out/m_3711401_sw_11_1_20150726.tif', '/contents/bin/out/m_3711402_ne_11_1_20150725.tif', '/contents/bin/out/m_3711402_nw_11_1_20150725.tif', '/contents/bin/out/m_3711402_se_11_1_20150726.tif', '/contents/bin/out/m_3711402_sw_11_1_20150726.tif', '/contents/bin/out/m_3711403_nw_11_1_20150725.tif', '/contents/bin/out/m_3711403_sw_11_1_20150725.tif']

# %%
i = 0
a = gdal.Open(output_files[i]).ReadAsArray()
a = np.moveaxis(a, 0 ,-1)[:,:,0]
b = 255-a
im = np.ma.masked_where(a<=10, a)

# %%
im
# Out:
# masked_array(data =
#  [[-- -- -- ..., -- -- --]
#  [-- -- -- ..., -- -- --]
#  [-- -- -- ..., -- -- --]
#  ...,
#  [-- -- -- ..., -- -- --]
#  [-- -- -- ..., -- -- --]
#  [-- -- -- ..., -- -- --]],
#              mask =
#  [[ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]
#  ...,
#  [ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]
#  [ True  True  True ...,  True  True  True]],
#        fill_value = 999999)

# %%
f, ax = plt.subplots(1,1, figsize=(20,20))
cax=ax.imshow(im)
f.colorbar(cax)

# %%
plt.hist(a[:,:,-1].reshape((7691*6610))/255, bins=20)
# Out:
# (array([  4.80935480e+07,   1.42941500e+06,   5.61323000e+05,
#           2.51474000e+05,   1.44763000e+05,   9.62270000e+04,
#           7.03790000e+04,   5.45120000e+04,   4.15560000e+04,
#           3.03270000e+04,   2.03470000e+04,   1.41630000e+04,
#           9.20100000e+03,   6.46900000e+03,   4.38300000e+03,
#           3.66000000e+03,   2.67600000e+03,   1.74700000e+03,
#           1.01600000e+03,   3.24000000e+02]),
#  array([ 0.00392157,  0.03529412,  0.06666667,  0.09803922,  0.12941176,
#          0.16078431,  0.19215686,  0.22352941,  0.25490196,  0.28627451,
#          0.31764706,  0.34901961,  0.38039216,  0.41176471,  0.44313725,
#          0.4745098 ,  0.50588235,  0.5372549 ,  0.56862745,  0.6       ,
#          0.63137255]),
#  <a list of 20 Patch objects>)

# %%
# Out:
# (7691, 6610)
