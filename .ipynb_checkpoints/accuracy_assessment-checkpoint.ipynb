# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import src.segnet_model as segnet_model
import src.segtools as segtools
from keras import optimizers
from glob import glob
import os
import json
from sklearn.metrics import confusion_matrix
import itertools
from PIL import Image
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
model_json = './fit_models/v6/seg_net.json' 
model_weight = './fit_models/v6/seg_net.h5' 
model = segnet_model.import_model(model_json, model_weight)
opt = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(loss='categorical_crossentropy', \
                     optimizer=opt, metrics=['categorical_accuracy'])
print('Model compiled!')
# Out:
# Model compiled!

# %%
# data type is wrong in validation
# get validation data to check things out
val_batch = 1000
val_generator = segtools.data_generator('/contents/images/val', batch_size=val_batch)
x_val, y_val = next(val_generator)
n_classes = 2

# %%
pr = model.predict(x_val)
predictions = []
for i in range(len(pr)):
    predictions.append(pr[i].reshape((256,256,n_classes)))
predictions = np.array(predictions)
norm_pred = segtools.normalize_stack(predictions[:,:,:,0])

# %%
f, ax = plt.subplots(2,2, figsize=(20, 16))
sample = np.random.randint(0, len(x_val))
sample = 101
x_ = x_val[sample].astype('float32')
y_ = y_val[sample].reshape(256,256,n_classes)[:,:,0]
ax[0,0].imshow(x_)
ax[0,0].set_title('Imagery sample:%s'%sample,fontsize=18)
ax[0,1].imshow(x_)
ax[0,1].imshow(y_, alpha=0.5)
ax[0,1].set_title('OSM road data',fontsize=18)
ax[1,0].imshow(x_)
#binary classify the road surface

y_hat = np.argmin(pr, axis=2).reshape(len(pr),256,256).astype('bool')
ax[1,0].imshow(x_)
ax[1,0].imshow(y_hat[sample], alpha=0.5)
ax[1,0].set_title('Modeled binary road est.',fontsize=18)

ax[1,1].imshow(x_)
im = ax[1,1].imshow(norm_pred[sample], alpha=0.9)
ax[1,1].set_title('Modeled continuous est.',fontsize=18)
cb = f.colorbar(im, ax=ax.ravel().tolist(),shrink=0.75)
cb.ax.tick_params(labelsize=18)
cb.set_label('Probability', fontsize=18)
f.savefig('./figures/example_quad_%s.png'%(sample), dpi=600, bbox_inches='tight')

# %%
def plot_overlay_and_confusion_matrix(x_val, y_val, y_hat, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues, ax0=None):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    
    n_classes = len(classes)
    model_acc_classes = 2*y_val.reshape(256,256,n_classes)[:,:,0] - \
        np.argmax(y_hat.reshape(256,256,n_classes), axis=2)
    #c, counts = np.unique(model_acc_classes, return_counts=True)
    # {'TN': -1, 'FP': 0, 'FN' : 1, 'TP': 2}
    #precision = counts[3]/(counts[3]+counts[0])
    #recall = counts[3]/(counts[3]+counts[1])
    #f1 = 2*((precision*recall)/(precision+recall))
    #print(precision, recall, f1)
    ax0.set_axis_off()
    cmap = mpl.colors.ListedColormap(['lightgrey','maroon','c', 'yellow'])
    ax0.imshow(x_val)
    im1 = ax0.imshow(model_acc_classes, cmap=cmap, alpha=0.5)
    bounds = [-0.65, 0.125, 0.9, 1.65]
    labels = ['true negative', 'false positive', 'false negative', 'true positive']
    cb = f.colorbar(im1, ax=ax0, orientation='horizontal')
    cb.set_ticks(bounds)
    cb.set_ticklabels(labels)
    cb.ax.tick_params(labelsize=18)
    f.savefig('./figures/example_acc_out_sample_%s.png'%(sample), dpi=600, bbox_inches='tight')
    #cm = confusion_matrix(np.argmax(y_hat, axis=1).flatten(), \
    #                              np.argmax(y_val, axis=1).flatten())
    #if normalize:
    #    cm = cm.astype('float32') / cm.sum(axis=1)[:, np.newaxis]
    #    print("Normalized confusion matrix")
    #else:
    #    print('Confusion matrix, without normalization')
    #print(cm)
    #    im2 = ax[1].imshow(cm, interpolation='nearest', cmap=cmap)
    #    #ax[1].set_title(title)
    #    cb2 = f.colorbar(im2, ax=ax[1])
    #    tick_marks = np.arange(len(classes))
    #    ax[1].set_xticks(tick_marks)
    #    ax[1].set_xticklabels(classes, rotation=45)
    #    ax[1].set_yticks(tick_marks)
    #    ax[1].set_yticklabels(classes)

    #    #fmt = '.2f' if normalize else 'd'
    #    #thresh = cm.max() / 2.
    #    #for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    #    #    ax[1].text(j, i, format(cm[i, j], fmt),
    #    #             horizontalalignment="center",
    #    #             color="white" if cm[i, j] > thresh else "black")

    #    #ax[1].tight_layout()
    #    ax[1].set_ylabel('True label')
    #    ax[1].set_xlabel('Predicted label')
    #return(f.savefig('./test.png'))

# %%
f, [ax0, ax1] = plt.subplots(1,2,figsize=(18,18))
plot_overlay_and_confusion_matrix(x_val[sample], y_val[sample], \
                                  pr[sample], classes=['road', 'non-road'],\
                                 title='Confusion Matrix', normalize=True, ax0=ax0)
plt.draw()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-ab6e4a0751a5> in <module>()
#       1 f, [ax0, ax1] = plt.subplots(1,2,figsize=(18,18))
# ----> 2 plot_overlay_and_confusion_matrix(x_val[sample], y_val[sample],                                   pr[sample], classes=['road', 'non-road'],                                 title='Confusion Matrix', normalize=True, ax0=ax0)
#       3 plt.draw()
#
# <ipython-input-90-66085b22713e> in plot_overlay_and_confusion_matrix(x_val, y_val, y_hat, classes, normalize, title, cmap, ax0)
#      26     cb.set_ticklabels(labels)
#      27     cb.ax.tick_params(labelsize=18)
# ---> 28     f.savefig('./figures/example_acc_out_sample_%s.png'%(sample), dpi=600, bbox_inches='tight')
#      29     #cm = confusion_matrix(np.argmax(y_hat, axis=1).flatten(), \
#      30     #                              np.argmax(y_val, axis=1).flatten())
#
# ...

# %%
plot_confusion_matrix(cnf_matrix, classes=['road', 'non-road'], title='Confusion matrix', normalize=True)
plt.savefig('./figures/val_confusion_matrix_sample_%s.png'%(sample)\
            , dpi=600, bbox_inches='tight')
# Out:
# Normalized confusion matrix
# [[ 0.69264544  0.30735456]
#  [ 0.00929152  0.99070848]]

# %%
N = 4
model_acc_classes = 2*y_val[sample].reshape(256,256,n_classes)[:,:,0] - \
    np.argmax(pr[sample].reshape(256,256,n_classes), axis=2)
c, counts = np.unique(model_acc_classes, return_counts=True)
# {'TN': -1, 'FP': 0, 'FN' : 1, 'TP': 2}
precision = counts[3]/(counts[3]+counts[0])
recall = counts[3]/(counts[3]+counts[1])
f1 = 2*((precision*recall)/(precision+recall))
print(precision, recall, f1)
f, ax = plt.subplots(1,1,figsize=(14,14))
ax.set_axis_off()
cmap = mpl.colors.ListedColormap(['lightgrey','maroon','c', 'yellow'])
ax.imshow(x_)
im = ax.imshow(model_acc_classes, cmap=cmap, alpha=0.5)
bounds = [-0.65, 0.125, 0.9, 1.65]
labels = ['true negative', 'false positive', 'false negative', 'true positive']
cb = f.colorbar(im, orientation='horizontal')
cb.set_ticks(bounds)
cb.set_ticklabels(labels)
cb.ax.tick_params(labelsize=18)
f.savefig('./figures/example_acc_out_sample_%s.png'%(sample), dpi=600, bbox_inches='tight')
# Out:
# 0.0196011431412 0.692645444566 0.0381234329215

# %%
cnf_matrix = confusion_matrix(np.argmax(pr, axis=2).flatten(), np.argmax(y_val, axis=2).flatten())
plot_confusion_matrix(cnf_matrix, classes=['road', 'non-road'], title='Confusion matrix', normalize=True)
plt.savefig('./figures/val_confusion_matrix.png', dpi=600, bbox_inches='tight')
# Out:
# Normalized confusion matrix
# [[ 0.6730769   0.3269231 ]
#  [ 0.01343328  0.98656672]]

# %%
model_acc_classes.max()
# Out:
# 2

# %%
samples = np.array([[129,250],[30, 10],[177,255]])

# %%
r, c = (2,2)
f, ax = plt.subplots(r,c, figsize=(20,20))
cmap = mpl.colors.ListedColormap(['lightgrey','maroon','c', 'yellow'])
for i in range(r):
    for j in range(c):
        #sample = np.random.randint(0, len(x_val)) 
        model_acc_classes = 2*y_val[samples[i,j]].reshape(256,256,n_classes)[:,:,0] - \
            np.argmax(pr[samples[i,j]].reshape(256,256,n_classes), axis=2)
        ax[i,j].imshow(x_val[samples[i,j]].astype('float32'))
        im = ax[i,j].imshow(model_acc_classes, cmap=cmap, vmin=-1, vmax=3, alpha=0.5)
        ax[i,j].set_title('Test data eval #%s'%samples[i,j], fontsize=18)
bounds = [-0.5, 0.5, 1.5, 2.5]
labels = ['true negative', 'false positive', 'false negative', 'true positive']
cb = f.colorbar(im, ax=ax.ravel().tolist(),shrink=0.75)
cb.set_ticks(bounds)
cb.set_ticklabels(labels)
cb.ax.tick_params(labelsize=18)
f.savefig('./figures/test_eval_quad.png', dpi=300, bbox_inches='tight')

# %%
# construct a confusion matrix using various masks...
def generate_threshold_mask(pr, thr):
    c = pr[:,:,0].reshape((pr.shape[0]*pr.shape[1])).astype('float16')
    input_shape = c.shape
    mask = np.zeros((c.shape[0])).astype('bool')
    mask[c>=thr] = True 
    return(mask)

# %%
t_min = 0
t_max = 1 
n_thr = 100 

target = y_val[:,:,0].reshape((y_val.shape[0]*y_val.shape[1])).astype('bool')
n_cells = target.shape[0]
n_c1 = np.sum(target)
n_c0 = n_cells - n_c1

#overall accuracy.
sensitivity = []
specificity = []
thresholds = np.linspace(t_min, t_max, n_thr)
for thr in thresholds:
    mask = generate_threshold_mask(pr, thr)
    sensitivity.append(np.sum((target & mask))/n_c1)
    specificity.append(np.sum((~target & ~mask))/n_c0)

# %%
sensitivity = np.array(sensitivity)
specificity = np.array(specificity)

# %%
f, ax = plt.subplots(1,1, figsize=(10,10))
ax.plot(thresholds, sensitivity, lw=5)
ax.plot(thresholds, specificity, lw=5, color='red')
ax.set_xlabel('Threshold', fontsize=24)
ax.tick_params('x', labelsize=20)
ax.tick_params('y', color='blue', labelsize=20)
ax.set_ylim(-0.01, 1.01)
#ax = ax.twinx()
#ax.set_ylabel(fontsize=20)
#ax.tick_params('y', color='blue', labelsize=20)
#ax.set_ylabel('Specificity', fontsize=20, color='red')
ax.grid()
mpld3.display(f)
